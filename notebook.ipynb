# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_training(path, info = None):
    df = pd.read_csv(path)

    # Identify epochs where val_loss is a new minimum so far
    running_min = df["val_loss"].expanding().min()
    improvement_mask = df["val_loss"] == running_min

    fig, ax1 = plt.subplots(figsize=(8, 5))

    # Plot loss curves
    l1, = ax1.plot(df["epoch"], df["train_loss"], label="Train Loss", color="tab:blue")
    l2, = ax1.plot(df["epoch"], df["val_loss"], label="Validation Loss", color="tab:orange")

    # Highlight every new best validation loss
    ax1.scatter(df.loc[improvement_mask, "epoch"], 
                df.loc[improvement_mask, "val_loss"], 
                color="red", marker="*", s=120, edgecolor="black", 
                label="New Best Val Loss")

    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.grid(True, linestyle='--', alpha=0.5)

    # Validation accuracy on secondary axis
    ax2 = ax1.twinx()
    l3, = ax2.plot(df["epoch"], df["val_iou"], color="tab:green", linestyle='--', label="Validation IoU")
    ax2.set_ylabel("Validation IoU")

    # Combine legends from both axes
    lines = [l1, l2, l3]
    labels = [line.get_label() for line in lines]
    # Add the new-best markers to the legend
    lines.append(ax1.scatter([], [], color="red", marker="*", s=100, edgecolor="black"))
    labels.append("New Best Val Loss")

    ax1.legend(lines, labels, loc="upper center", bbox_to_anchor=(0.5, 1.18), ncol=4, frameon=True)

    if info:
        plt.title(f"Training/Validation Loss and Validation IoU ({info})")
    else:
        plt.title(f"Training/Validation Loss and Validation IoU")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # COD

# %% [markdown]
# ## LoRA

# %%
path = "checkpoints_old/lora/cod/2025-10-18_10-36-37/training_log.csv"
plot_training(path, "lr=0.001, batch_size=8")

# %%
path = "checkpoints_old/lora/cod/2025-10-18_14-44-45/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=8")

# %%
path = "checkpoints_old/lora/cod/2025-10-20_22-01-00/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=4")

# %%
path = "checkpoints_old/lora/cod/2025-10-21_12-17-23/training_log.csv"
plot_training(path, "lr=0.001, batch_size=4")

# %% [markdown]
# ### Correct normalization

# %%
path = "checkpoints/lora/cod/2025-10-25_20-26-55/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# #### Point-prompt

# %%
path = "checkpoints/lora/cod/2025-10-28_15-56-14/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# ## Adapter

# %%
path = "checkpoints_old/adapter/cod/2025-10-18_10-52-02/training_log.csv"
plot_training(path, "lr=0.001, batch_size=8")

# %%
path = "checkpoints_old/adapter/cod/2025-10-18_15-15-16/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=8")

# %%
path = "checkpoints_old/adapter/cod/2025-10-20_22-08-04/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=4")

# %%
path = "checkpoints_old/adapter/cod/2025-10-21_12-22-51/training_log.csv"
plot_training(path, "lr=0.001, batch_size=4")

# %% [markdown]
# ### Correct normalization

# %%
path = "checkpoints/adapter/cod/2025-10-25_20-36-10/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# #### Point-prompt

# %%
path = "checkpoints/adapter/cod/2025-10-28_17-35-47/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# ## Adapter and LoRA

# %%
path = "checkpoints_old/adapter_lora/cod/2025-10-18_18-24-43/training_log.csv"
plot_training(path, "lr=0.001, batch_size=8")

# %%
path = "checkpoints_old/adapter_lora/cod/2025-10-20_22-13-07/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=4")

# %%
path = "checkpoints_old/adapter_lora/cod/2025-10-21_12-17-49/training_log.csv"
plot_training(path, "lr=0.001, batch_size=4")

# %% [markdown]
# ### Correct normalization

# %%
path = "checkpoints/adapter_lora/cod/2025-10-25_22-52-26/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# #### Point-prompt

# %%
path = "checkpoints/adapter_lora/cod/2025-10-28_17-46-22/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# # SHADOW

# %% [markdown]
# ## LoRA

# %%
path = "checkpoints_old/lora/shadow/2025-10-21_12-23-12/training_log.csv"
plot_training(path, "lr=0.001, batch_size=4")

# %%
path = "checkpoints_old/lora/shadow/2025-10-21_16-02-43/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=4")

# %% [markdown]
# ### Correct normalization

# %%
path = "checkpoints/lora/shadow/2025-10-25_23-19-27/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %%
path = "checkpoints/lora/shadow/2025-10-30_16-51-14/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# #### Point-prompt

# %%
path = "checkpoints/lora/shadow/2025-10-28_18-20-58/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %%
path = "checkpoints/lora/shadow/2025-10-30_16-47-00/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# ## Adapter

# %%
path = "checkpoints_old/adapter/shadow/2025-10-21_12-23-23/training_log.csv"
plot_training(path, "lr=0.001, batch_size=4")

# %%
path = "checkpoints_old/adapter/shadow/2025-10-21_15-59-45/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=4")

# %% [markdown]
# ### Correct normalization

# %%
path = "checkpoints/adapter/shadow/2025-10-26_00-13-35/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %%
path = "checkpoints/adapter/shadow/2025-10-30_16-49-04/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# #### Point-prompt

# %%
path = "checkpoints/adapter/shadow/2025-10-28_18-42-33/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %%
path = "checkpoints/adapter/shadow/2025-10-30_16-49-04/training_log."
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# ## Adapter and LoRA

# %%
path = "checkpoints_old/adapter_lora/shadow/2025-10-21_13-57-35/training_log.csv"
plot_training(path, "lr=0.001, batch_size=4")

# %%
path = "checkpoints_old/adapter_lora/shadow/2025-10-21_15-58-11/training_log.csv"
plot_training(path, "lr=0.0001, batch_size=4")

# %% [markdown]
# ### Correct normalization

# %%
path = "checkpoints/adapter_lora/cod/2025-10-25_22-52-26/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")

# %% [markdown]
# #### Point-prompt

# %%
path = "checkpoints/adapter_lora/shadow/2025-10-28_21-39-30/training_log.csv"
plot_training(path, "lr=0.0002, batch_size=4")
